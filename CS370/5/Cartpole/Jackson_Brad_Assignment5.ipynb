# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 20
# Scores: (min: 20, avg: 20, max: 20)
#
# Run: 2, exploration: 0.9369146928798039, score: 14
# Scores: (min: 14, avg: 17, max: 20)
#
# Run: 3, exploration: 0.7705488893118823, score: 40
# Scores: (min: 14, avg: 24.666666666666668, max: 40)
#
# Run: 4, exploration: 0.7328768546436799, score: 11
# Scores: (min: 11, avg: 21.25, max: 40)
#
# Run: 5, exploration: 0.5790496471185967, score: 48
# Scores: (min: 11, avg: 26.6, max: 48)
#
# Run: 6, exploration: 0.4810273709480478, score: 38
# Scores: (min: 11, avg: 28.5, max: 48)
#
# Run: 7, exploration: 0.4036245882390106, score: 36
# Scores: (min: 11, avg: 29.571428571428573, max: 48)
#
# Run: 8, exploration: 0.3420891339682016, score: 34
# Scores: (min: 11, avg: 30.125, max: 48)
#
# Run: 9, exploration: 0.30028896908517405, score: 27
# Scores: (min: 11, avg: 29.77777777777778, max: 48)
#
# Run: 10, exploration: 0.2649210072611673, score: 26
# Scores: (min: 11, avg: 29.4, max: 48)
#
# ...

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
# Experiment 2
GAMMA = 0.90  # Discount factor
LEARNING_RATE = 0.002  # Learning rate

EXPLORATION_MAX = 0.9  # Maximum exploration rate
EXPLORATION_MIN = 0.01  # Minimum exploration rate
EXPLORATION_DECAY = 0.99  # Exploration decay

cartpole()
# Out:
# Run: 1, exploration: 0.9, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.7818712314920805, score: 21
# Scores: (min: 13, avg: 17, max: 21)
#
# Run: 3, exploration: 0.572566937457484, score: 32
# Scores: (min: 13, avg: 22, max: 32)
#
# Run: 4, exploration: 0.49741512944614663, score: 15
# Scores: (min: 13, avg: 20.25, max: 32)
#
# Run: 5, exploration: 0.43649223324674663, score: 14
# Scores: (min: 13, avg: 19, max: 32)
#
# Run: 6, exploration: 0.3947557516289198, score: 11
# Scores: (min: 11, avg: 17.666666666666668, max: 32)
#
# Run: 7, exploration: 0.3606161876563865, score: 10
# Scores: (min: 10, avg: 16.571428571428573, max: 32)
#
# Run: 8, exploration: 0.32287346791370275, score: 12
# Scores: (min: 10, avg: 16, max: 32)
#
# Run: 9, exploration: 0.2890809671083123, score: 12
# Scores: (min: 10, avg: 15.555555555555555, max: 32)
#
# Run: 10, exploration: 0.2614396448789674, score: 11
# Scores: (min: 10, avg: 15.1, max: 32)
#
# ...

# %%
# Experiment 3
GAMMA = 0.95  # Discount factor
LEARNING_RATE = 0.001  # Learning rate

EXPLORATION_MAX = 0.8  # Maximum exploration rate
EXPLORATION_MIN = 0.01  # Minimum exploration rate
EXPLORATION_DECAY = 0.995  # Exploration decay

cartpole()
# Out:
# Run: 1, exploration: 0.7647116626860477, score: 29
# Scores: (min: 29, avg: 29, max: 29)
#
# Run: 2, exploration: 0.6289235581474344, score: 40
# Scores: (min: 29, avg: 34.5, max: 40)
#
# Run: 3, exploration: 0.5384103079160317, score: 32
# Scores: (min: 29, avg: 33.666666666666664, max: 40)
#
# Run: 4, exploration: 0.48461634919258256, score: 22
# Scores: (min: 22, avg: 30.75, max: 40)
#
# Run: 5, exploration: 0.4655675554722388, score: 9
# Scores: (min: 9, avg: 26.4, max: 40)
#
# Run: 6, exploration: 0.44951508729306644, score: 8
# Scores: (min: 8, avg: 23.333333333333332, max: 40)
#
# Run: 7, exploration: 0.4232736582472579, score: 13
# Scores: (min: 8, avg: 21.857142857142858, max: 40)
#
# Run: 8, exploration: 0.39065243315482845, score: 17
# Scores: (min: 8, avg: 21.25, max: 40)
#
# Run: 9, exploration: 0.35162134375075416, score: 22
# Scores: (min: 8, avg: 21.333333333333332, max: 40)
#
# Run: 10, exploration: 0.336111178019427, score: 10
# Scores: (min: 8, avg: 20.2, max: 40)
# ...

# %% [markdown]
# # Reinforcement Learning and the Cartpole Problem
#
# - **Goal:** The agent's goal is to balance a pole on a cart for as long as possible (Sutton & Barto, 2018).
# - **State Values:** The state is a 4D array containing cart position, cart velocity, pole angle, and pole velocity at the tip.
# - **Actions:** The agent can move the cart to the left or right.
# - **Algorithm:** The problem uses Deep Q-Learning, which combines Q-Learning with deep neural networks (Mnih et al., 2013).
#
# ## Experience Replay in the Cartpole Problem
#
# - **How it Works:** Experience Replay stores the agent's experiences at each time step and randomly samples them for training, breaking the correlation between consecutive experiences for better model convergence.
# - **Effect of Discount Factor:** The discount factor (gamma) is used to calculate future rewards, prioritizing immediate rewards over distant ones (Sutton & Barto, 2018).
#
# ## Neural Networks in Deep Q-Learning
#
# - **Neural Network Architecture:** The network used here has two hidden layers with 24 nodes each. The input is the state, and the output is the Q-value of each action.
# - **Efficiency of Neural Network:** The neural network allows the agent to generalize from the observed states to unseen states, making the Q-Learning algorithm more efficient.
# - **Effect of Learning Rate:** The learning rate controls how much the network learns from new experiences. A lower learning rate led to the problem being solved more quickly in the experiments, suggesting more stable and effective learning.
#
# ## References
# 1. Mnih, V., et al. (2013). Playing atari with deep reinforcement learning. [Playing atari with deep reinforcement learning](https://doi.org/10.48550/arXiv.1312.5602)
# 2. Sutton, R. S., & Barto, A. G. (2018). Reinforcement learning: An introduction. MIT press. [Carnegia Mellon University](https://www.andrew.cmu.edu/course/10-703/textbook/BartoSutton.pdf)
